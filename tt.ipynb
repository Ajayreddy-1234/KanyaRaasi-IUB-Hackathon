# %%
import os
import random
from PIL import Image, ImageEnhance, ImageOps

def load_images_from_folder(folder):
    images = []
    # Only process files with these image file extensions
    valid_extensions = ['.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif']
    for filename in os.listdir(folder):
        # Check the file extension before opening
        if any(filename.lower().endswith(ext) for ext in valid_extensions):
            img_path = os.path.join(folder, filename)
            with Image.open(img_path) as img:
                img = img.convert("RGBA")
                images.append((img, filename, folder.split(os.sep)[-1]))
    return images

def check_overlap(new_box, boxes):
    for box in boxes:
        if (new_box[0] < box[2] and new_box[2] > box[0] and
            new_box[1] < box[3] and new_box[3] > box[1]):
            return True
    return False

def apply_transformations(img):
    img = img.rotate(random.randint(-45, 45), expand=True)
    img = ImageEnhance.Brightness(img).enhance(random.uniform(0.7, 1.3))
    img = ImageEnhance.Contrast(img).enhance(random.uniform(0.8, 1.2))
    if random.choice([True, False]):
        img = ImageOps.flip(img)
    if random.choice([True, False]):
        img = ImageOps.mirror(img)
    return img

def combine_images(image_list, background_size):
    background = Image.new('RGBA', background_size, (255, 255, 255, 255))
    annotations = []
    occupied_areas = []

    for img, filename, label in image_list:
        img = apply_transformations(img)
        scale_factor = min(background_size[0] / img.width, background_size[1] / img.height, 1)
        img = img.resize((int(img.width * scale_factor), int(img.height * scale_factor)), Image.LANCZOS)
        
        placed = False
        attempts = 0
        while not placed and attempts < 50:
            x, y = random.randint(0, background_size[0] - img.width), random.randint(0, background_size[1] - img.height)
            new_box = [x, y, x + img.width, y + img.height]
            if not check_overlap(new_box, occupied_areas):
                background.paste(img, (x, y), img)
                occupied_areas.append(new_box)
                annotations.append({'class': label, 'bbox': new_box, 'filename': filename})
                placed = True
            attempts += 1

    return background.convert('RGB'), annotations

def create_dataset(base_folder, num_images=200, min_items_per_image=5, max_items_per_image=10, fixed_size=(2048, 2048)):
    categories = [d for d in os.listdir(base_folder) if os.path.isdir(os.path.join(base_folder, d))]
    output_folder = os.path.join(base_folder, 'combined_dataset')
    os.makedirs(output_folder, exist_ok=True)

    for i in range(num_images):
        num_items = random.randint(min_items_per_image, max_items_per_image)
        selected_images = []
        selected_categories = random.sample(categories, min(4, len(categories)))

        while len(selected_images) < num_items:
            category_folder = random.choice(selected_categories)
            images = load_images_from_folder(os.path.join(base_folder, category_folder))
            if images:
                selected_image = random.choice(images)
                selected_images.append(selected_image)
                if len(selected_images) >= 4:
                    selected_categories = categories  # Allow any category after initial requirement

        combined_image, annotations = combine_images(selected_images, fixed_size)
        combined_image.save(os.path.join(output_folder, f'combined_{i}.jpg'))
        print(f"Created image {i} at {output_folder}/combined_{i}.jpg with {len(selected_images)} items.")

        with open(os.path.join(output_folder, f'combined_{i}.txt'), 'w') as f:
            for annotation in annotations:
                f.write(f"{annotation['class']} {annotation['bbox'][0]} {annotation['bbox'][1]} {annotation['bbox'][2]} {annotation['bbox'][3]}\n")

# Example usage:
create_dataset('archive')
# Out:
# Created image 0 at archive/combined_dataset/combined_0.jpg with 9 items.
# Created image 1 at archive/combined_dataset/combined_1.jpg with 10 items.
# Created image 2 at archive/combined_dataset/combined_2.jpg with 5 items.
# Created image 3 at archive/combined_dataset/combined_3.jpg with 6 items.
# Created image 4 at archive/combined_dataset/combined_4.jpg with 5 items.
# Created image 5 at archive/combined_dataset/combined_5.jpg with 5 items.
# Created image 6 at archive/combined_dataset/combined_6.jpg with 7 items.
# Created image 7 at archive/combined_dataset/combined_7.jpg with 6 items.
# Created image 8 at archive/combined_dataset/combined_8.jpg with 9 items.
# Created image 9 at archive/combined_dataset/combined_9.jpg with 7 items.
# Created image 10 at archive/combined_dataset/combined_10.jpg with 10 items.
# Created image 11 at archive/combined_dataset/combined_11.jpg with 5 items.
# Created image 12 at archive/combined_dataset/combined_12.jpg with 7 items.
# Created image 13 at archive/combined_dataset/combined_13.jpg with 10 items.
# Created image 14 at archive/combined_dataset/combined_14.jpg with 8 items.
# Created image 15 at archive/combined_dataset/combined_15.jpg with 8 items.
# Created image 16 at archive/combined_dataset/combined_16.jpg with 9 items.
# Created image 17 at archive/combined_dataset/combined_17.jpg with 10 items.
# Created image 18 at archive/combined_dataset/combined_18.jpg with 6 items.
# Created image 19 at archive/combined_dataset/combined_19.jpg with 10 items.
# Created image 20 at archive/combined_dataset/combined_20.jpg with 10 items.
# Created image 21 at archive/combined_dataset/combined_21.jpg with 7 items.
# Created image 22 at archive/combined_dataset/combined_22.jpg with 8 items.
# Created image 23 at archive/combined_dataset/combined_23.jpg with 8 items.
# Created image 24 at archive/combined_dataset/combined_24.jpg with 10 items.
# Created image 25 at archive/combined_dataset/combined_25.jpg with 10 items.
# Created image 26 at archive/combined_dataset/combined_26.jpg with 6 items.
# Created image 27 at archive/combined_dataset/combined_27.jpg with 10 items.
# Created image 28 at archive/combined_dataset/combined_28.jpg with 5 items.
# Created image 29 at archive/combined_dataset/combined_29.jpg with 8 items.
# Created image 30 at archive/combined_dataset/combined_30.jpg with 6 items.
# Created image 31 at archive/combined_dataset/combined_31.jpg with 8 items.
# Created image 32 at archive/combined_dataset/combined_32.jpg with 6 items.
# Created image 33 at archive/combined_dataset/combined_33.jpg with 6 items.
# Created image 34 at archive/combined_dataset/combined_34.jpg with 9 items.
# Created image 35 at archive/combined_dataset/combined_35.jpg with 7 items.
# Created image 36 at archive/combined_dataset/combined_36.jpg with 7 items.
# Created image 37 at archive/combined_dataset/combined_37.jpg with 5 items.
# Created image 38 at archive/combined_dataset/combined_38.jpg with 7 items.
# Created image 39 at archive/combined_dataset/combined_39.jpg with 10 items.
# Created image 40 at archive/combined_dataset/combined_40.jpg with 9 items.
# Created image 41 at archive/combined_dataset/combined_41.jpg with 9 items.
# Created image 42 at archive/combined_dataset/combined_42.jpg with 6 items.
# Created image 43 at archive/combined_dataset/combined_43.jpg with 5 items.
# Created image 44 at archive/combined_dataset/combined_44.jpg with 10 items.
# Created image 45 at archive/combined_dataset/combined_45.jpg with 9 items.
# Created image 46 at archive/combined_dataset/combined_46.jpg with 6 items.
# Created image 47 at archive/combined_dataset/combined_47.jpg with 8 items.
# Created image 48 at archive/combined_dataset/combined_48.jpg with 6 items.
# Created image 49 at archive/combined_dataset/combined_49.jpg with 8 items.
# Created image 50 at archive/combined_dataset/combined_50.jpg with 6 items.
# Created image 51 at archive/combined_dataset/combined_51.jpg with 9 items.
# Created image 52 at archive/combined_dataset/combined_52.jpg with 10 items.
# Created image 53 at archive/combined_dataset/combined_53.jpg with 10 items.
# Created image 54 at archive/combined_dataset/combined_54.jpg with 10 items.
# Created image 55 at archive/combined_dataset/combined_55.jpg with 9 items.
# Created image 56 at archive/combined_dataset/combined_56.jpg with 8 items.
# Created image 57 at archive/combined_dataset/combined_57.jpg with 7 items.
# Created image 58 at archive/combined_dataset/combined_58.jpg with 9 items.
# Created image 59 at archive/combined_dataset/combined_59.jpg with 6 items.
# Created image 60 at archive/combined_dataset/combined_60.jpg with 7 items.
# Created image 61 at archive/combined_dataset/combined_61.jpg with 6 items.
# Created image 62 at archive/combined_dataset/combined_62.jpg with 6 items.
# Created image 63 at archive/combined_dataset/combined_63.jpg with 9 items.
# Created image 64 at archive/combined_dataset/combined_64.jpg with 5 items.
# Created image 65 at archive/combined_dataset/combined_65.jpg with 9 items.
# Created image 66 at archive/combined_dataset/combined_66.jpg with 7 items.
# Created image 67 at archive/combined_dataset/combined_67.jpg with 7 items.
# Created image 68 at archive/combined_dataset/combined_68.jpg with 5 items.
# Created image 69 at archive/combined_dataset/combined_69.jpg with 10 items.
# Created image 70 at archive/combined_dataset/combined_70.jpg with 6 items.
# Created image 71 at archive/combined_dataset/combined_71.jpg with 6 items.
# Created image 72 at archive/combined_dataset/combined_72.jpg with 10 items.
# Created image 73 at archive/combined_dataset/combined_73.jpg with 8 items.
# Created image 74 at archive/combined_dataset/combined_74.jpg with 6 items.
# Created image 75 at archive/combined_dataset/combined_75.jpg with 6 items.
# Created image 76 at archive/combined_dataset/combined_76.jpg with 8 items.
# Created image 77 at archive/combined_dataset/combined_77.jpg with 8 items.
# Created image 78 at archive/combined_dataset/combined_78.jpg with 9 items.
# Created image 79 at archive/combined_dataset/combined_79.jpg with 10 items.
# Created image 80 at archive/combined_dataset/combined_80.jpg with 5 items.
# Created image 81 at archive/combined_dataset/combined_81.jpg with 7 items.
# Created image 82 at archive/combined_dataset/combined_82.jpg with 9 items.
# Created image 83 at archive/combined_dataset/combined_83.jpg with 9 items.
# Created image 84 at archive/combined_dataset/combined_84.jpg with 8 items.
# Created image 85 at archive/combined_dataset/combined_85.jpg with 6 items.
# Created image 86 at archive/combined_dataset/combined_86.jpg with 5 items.
# Created image 87 at archive/combined_dataset/combined_87.jpg with 9 items.
# Created image 88 at archive/combined_dataset/combined_88.jpg with 10 items.
# Created image 89 at archive/combined_dataset/combined_89.jpg with 7 items.
# Created image 90 at archive/combined_dataset/combined_90.jpg with 7 items.
# Created image 91 at archive/combined_dataset/combined_91.jpg with 10 items.
# Created image 92 at archive/combined_dataset/combined_92.jpg with 8 items.
# Created image 93 at archive/combined_dataset/combined_93.jpg with 5 items.
# Created image 94 at archive/combined_dataset/combined_94.jpg with 9 items.
# Created image 95 at archive/combined_dataset/combined_95.jpg with 8 items.
# Created image 96 at archive/combined_dataset/combined_96.jpg with 10 items.
# Created image 97 at archive/combined_dataset/combined_97.jpg with 9 items.
# Created image 98 at archive/combined_dataset/combined_98.jpg with 6 items.
# Created image 99 at archive/combined_dataset/combined_99.jpg with 10 items.
# Created image 100 at archive/combined_dataset/combined_100.jpg with 10 items.
# Created image 101 at archive/combined_dataset/combined_101.jpg with 10 items.
# Created image 102 at archive/combined_dataset/combined_102.jpg with 7 items.
# Created image 103 at archive/combined_dataset/combined_103.jpg with 7 items.
# Created image 104 at archive/combined_dataset/combined_104.jpg with 6 items.
# Created image 105 at archive/combined_dataset/combined_105.jpg with 5 items.
# Created image 106 at archive/combined_dataset/combined_106.jpg with 6 items.
# Created image 107 at archive/combined_dataset/combined_107.jpg with 8 items.
# Created image 108 at archive/combined_dataset/combined_108.jpg with 9 items.
# Created image 109 at archive/combined_dataset/combined_109.jpg with 7 items.
# Created image 110 at archive/combined_dataset/combined_110.jpg with 8 items.
# Created image 111 at archive/combined_dataset/combined_111.jpg with 7 items.
# Created image 112 at archive/combined_dataset/combined_112.jpg with 9 items.
# Created image 113 at archive/combined_dataset/combined_113.jpg with 8 items.
# Created image 114 at archive/combined_dataset/combined_114.jpg with 5 items.
# Created image 115 at archive/combined_dataset/combined_115.jpg with 6 items.
# Created image 116 at archive/combined_dataset/combined_116.jpg with 9 items.
# Created image 117 at archive/combined_dataset/combined_117.jpg with 7 items.
# Created image 118 at archive/combined_dataset/combined_118.jpg with 9 items.
# Created image 119 at archive/combined_dataset/combined_119.jpg with 8 items.
# Created image 120 at archive/combined_dataset/combined_120.jpg with 10 items.
# Created image 121 at archive/combined_dataset/combined_121.jpg with 10 items.
# Created image 122 at archive/combined_dataset/combined_122.jpg with 6 items.
# Created image 123 at archive/combined_dataset/combined_123.jpg with 7 items.
# Created image 124 at archive/combined_dataset/combined_124.jpg with 7 items.
# Created image 125 at archive/combined_dataset/combined_125.jpg with 6 items.
# Created image 126 at archive/combined_dataset/combined_126.jpg with 7 items.
# Created image 127 at archive/combined_dataset/combined_127.jpg with 7 items.
# Created image 128 at archive/combined_dataset/combined_128.jpg with 8 items.
# Created image 129 at archive/combined_dataset/combined_129.jpg with 9 items.
# Created image 130 at archive/combined_dataset/combined_130.jpg with 8 items.
# Created image 131 at archive/combined_dataset/combined_131.jpg with 6 items.
# Created image 132 at archive/combined_dataset/combined_132.jpg with 9 items.
# Created image 133 at archive/combined_dataset/combined_133.jpg with 10 items.
# Created image 134 at archive/combined_dataset/combined_134.jpg with 5 items.
# Created image 135 at archive/combined_dataset/combined_135.jpg with 6 items.
# Created image 136 at archive/combined_dataset/combined_136.jpg with 9 items.
# Created image 137 at archive/combined_dataset/combined_137.jpg with 7 items.
# Created image 138 at archive/combined_dataset/combined_138.jpg with 6 items.
# Created image 139 at archive/combined_dataset/combined_139.jpg with 9 items.
# Created image 140 at archive/combined_dataset/combined_140.jpg with 9 items.
# Created image 141 at archive/combined_dataset/combined_141.jpg with 10 items.
# Created image 142 at archive/combined_dataset/combined_142.jpg with 8 items.
# Created image 143 at archive/combined_dataset/combined_143.jpg with 10 items.
# Created image 144 at archive/combined_dataset/combined_144.jpg with 7 items.
# Created image 145 at archive/combined_dataset/combined_145.jpg with 5 items.
# Created image 146 at archive/combined_dataset/combined_146.jpg with 10 items.
# Created image 147 at archive/combined_dataset/combined_147.jpg with 10 items.
# Created image 148 at archive/combined_dataset/combined_148.jpg with 10 items.
# Created image 149 at archive/combined_dataset/combined_149.jpg with 7 items.
# Created image 150 at archive/combined_dataset/combined_150.jpg with 9 items.
# Created image 151 at archive/combined_dataset/combined_151.jpg with 8 items.
# Created image 152 at archive/combined_dataset/combined_152.jpg with 8 items.
# Created image 153 at archive/combined_dataset/combined_153.jpg with 9 items.
# Created image 154 at archive/combined_dataset/combined_154.jpg with 6 items.
# Created image 155 at archive/combined_dataset/combined_155.jpg with 7 items.
# Created image 156 at archive/combined_dataset/combined_156.jpg with 8 items.
# Created image 157 at archive/combined_dataset/combined_157.jpg with 10 items.
# Created image 158 at archive/combined_dataset/combined_158.jpg with 6 items.
# Created image 159 at archive/combined_dataset/combined_159.jpg with 7 items.
# Created image 160 at archive/combined_dataset/combined_160.jpg with 9 items.
# Created image 161 at archive/combined_dataset/combined_161.jpg with 6 items.
# Created image 162 at archive/combined_dataset/combined_162.jpg with 6 items.
# Created image 163 at archive/combined_dataset/combined_163.jpg with 9 items.
# Created image 164 at archive/combined_dataset/combined_164.jpg with 9 items.
# Created image 165 at archive/combined_dataset/combined_165.jpg with 10 items.
# Created image 166 at archive/combined_dataset/combined_166.jpg with 9 items.
# Created image 167 at archive/combined_dataset/combined_167.jpg with 9 items.
# Created image 168 at archive/combined_dataset/combined_168.jpg with 8 items.
# Created image 169 at archive/combined_dataset/combined_169.jpg with 6 items.
# Created image 170 at archive/combined_dataset/combined_170.jpg with 8 items.
# Created image 171 at archive/combined_dataset/combined_171.jpg with 7 items.
# Created image 172 at archive/combined_dataset/combined_172.jpg with 7 items.
# Created image 173 at archive/combined_dataset/combined_173.jpg with 10 items.
# Created image 174 at archive/combined_dataset/combined_174.jpg with 6 items.
# Created image 175 at archive/combined_dataset/combined_175.jpg with 10 items.
# Created image 176 at archive/combined_dataset/combined_176.jpg with 9 items.
# Created image 177 at archive/combined_dataset/combined_177.jpg with 6 items.
# Created image 178 at archive/combined_dataset/combined_178.jpg with 5 items.
# Created image 179 at archive/combined_dataset/combined_179.jpg with 7 items.
# Created image 180 at archive/combined_dataset/combined_180.jpg with 6 items.
# Created image 181 at archive/combined_dataset/combined_181.jpg with 8 items.
# Created image 182 at archive/combined_dataset/combined_182.jpg with 7 items.
# Created image 183 at archive/combined_dataset/combined_183.jpg with 7 items.
# Created image 184 at archive/combined_dataset/combined_184.jpg with 9 items.
# Created image 185 at archive/combined_dataset/combined_185.jpg with 9 items.
# Created image 186 at archive/combined_dataset/combined_186.jpg with 8 items.
# Created image 187 at archive/combined_dataset/combined_187.jpg with 10 items.
# Created image 188 at archive/combined_dataset/combined_188.jpg with 7 items.
# Created image 189 at archive/combined_dataset/combined_189.jpg with 8 items.
# Created image 190 at archive/combined_dataset/combined_190.jpg with 9 items.
# Created image 191 at archive/combined_dataset/combined_191.jpg with 10 items.
# Created image 192 at archive/combined_dataset/combined_192.jpg with 10 items.
# Created image 193 at archive/combined_dataset/combined_193.jpg with 9 items.
# Created image 194 at archive/combined_dataset/combined_194.jpg with 7 items.
# Created image 195 at archive/combined_dataset/combined_195.jpg with 10 items.
# Created image 196 at archive/combined_dataset/combined_196.jpg with 10 items.
# Created image 197 at archive/combined_dataset/combined_197.jpg with 8 items.
# Created image 198 at archive/combined_dataset/combined_198.jpg with 8 items.
# Created image 199 at archive/combined_dataset/combined_199.jpg with 8 items.

# %%
import os
import random
from PIL import Image, ImageEnhance

def load_images_from_folder(folder):
    images = []
    for filename in os.listdir(folder):
        img_path = os.path.join(folder, filename)
        with Image.open(img_path) as img:
            img = img.convert("RGBA")
            images.append((img, filename, folder.split(os.sep)[-1]))
    return images

def check_overlap(new_box, boxes):
    for box in boxes:
        if (new_box[0] < box[2] and new_box[2] > box[0] and
            new_box[1] < box[3] and new_box[3] > box[1]):
            return True
    return False

def apply_transformations(img):
    angle = random.randint(-45, 45)
    img = img.rotate(angle, expand=True)
    enhancer = ImageEnhance.Brightness(img)
    factor = random.uniform(0.7, 1.3)
    img = enhancer.enhance(factor)
    return img

def combine_images(image_list, background_size, min_items):
    background = Image.new('RGBA', background_size, (255, 255, 255, 255))
    annotations = []
    occupied_areas = []

    for img, filename, label in image_list:
        img = apply_transformations(img)
        scale_x = background_size[0] / img.size[0]
        scale_y = background_size[1] / img.size[1]
        scale_factor = min(scale_x, scale_y, 1)
        new_size = (int(img.size[0] * scale_factor), int(img.size[1] * scale_factor))
        img = img.resize(new_size)

        placed = False
        attempts = 0
        while not placed and attempts < 50:
            max_x = max(background_size[0] - img.size[0], 0)
            max_y = max(background_size[1] - img.size[1], 0)
            x = random.randint(0, max_x)
            y = random.randint(0, max_y)
            new_box = [x, y, x + img.size[0], y + img.size[1]]
            if not check_overlap(new_box, occupied_areas):
                background.paste(img, (x, y), img)
                occupied_areas.append(new_box)
                annotations.append({
                    'class': label,
                    'bbox': new_box,
                    'filename': filename
                })
                placed = True
            attempts += 1

    return background.convert('RGB'), annotations

def create_dataset(base_folder, num_images=200, min_items_per_image=5, max_items_per_image=10, max_size=(2048, 2048)):
    categories = [os.path.join(base_folder, d) for d in os.listdir(base_folder) if os.path.isdir(os.path.join(base_folder, d))]
    output_folder = os.path.join(base_folder, 'combined_dataset')
    os.makedirs(output_folder, exist_ok=True)

    for i in range(num_images):
        background_size = (random.randint(500, max_size[0]), random.randint(500, max_size[1]))
        selected_images = []
        while len(selected_images) < min_items_per_image:
            category_folder = random.choice(categories)
            images = load_images_from_folder(category_folder)
            if images:
                selected_image = random.choice(images)
                selected_images.append(selected_image)
        
        print(f"Debug: Attempt {i+1}, Number of selected images: {len(selected_images)}")  # Debug output

        if len(selected_images) < min_items_per_image:
            print("Skipping due to insufficient images after selection.")
            continue

        num_items = random.randint(min_items_per_image, min(len(selected_images), max_items_per_image))
        if len(selected_images) < num_items:
            print("Error in calculation of num_items, adjusting to length of selected_images.")
            num_items = len(selected_images)

        selected_images = random.sample(selected_images, num_items)

        combined_image, annotations = combine_images(selected_images, background_size, min_items_per_image)
        combined_image.save(os.path.join(output_folder, f'combined_{i}.jpg'))

        with open(os.path.join(output_folder, f'combined_{i}.txt'), 'w') as f:
            for annotation in annotations:
                f.write(f"{annotation['class']} {annotation['bbox'][0]} {annotation['bbox'][1]} {annotation['bbox'][2]} {annotation['bbox'][3]}\n")

# Example usage:
create_dataset('archive')
